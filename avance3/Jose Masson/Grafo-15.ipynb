# %% [markdown]
# # Degree Distribution (15 minutos)

# %% [markdown]
# Para esta parte se procederá a trabajar con el top 3 donde existen la mayor cantidad de conexiones
# * Aeropuerto
# * Mall del Sur
# * City Mall

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Aeropuerto

# %%
aeropuerto = open("./15/aeropuertoPeso2.csv", 'rb')
aeropuerto.readline()
conexiones_aeropuerto = nx.read_edgelist(aeropuerto, delimiter=',', nodetype=int, data=(('weight',int),))
aeropuerto.close()

# %%
degrees_aeropuerto = conexiones_aeropuerto.degree()

degrees = list(degrees_aeropuerto.values())

degrees = sorted(set(degrees))
histogram = [list(degrees_aeropuerto.values()).count(x) for x in degrees]

# %%
plt.figure()
plt.plot(degrees, histogram)
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title('Aeropuerto')
plt.savefig("aeropuerto_15.png", dpi=500)
plt.show()

# %%
plt.figure()
plt.loglog(degrees,histogram, basex=10, basey=10) # Log Log
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title('Aeropuerto')
plt.savefig("aeropuerto_15_pl.png", dpi=500)
plt.show()

# %%
items = list(degrees_aeropuerto.items())
items.sort(key=lambda x: x[1], reverse=True)

minimum_degree = items[-1][1]
maximum_degree = items[0][1]

# %%
print("Minimum degree: {:.2f}".format(minimum_degree)) 
print("Maximum degree: {:.2f}".format(maximum_degree))
print("Node ID with maximum degree: {}".format(items[0][0]))
print("Node ID with minimum degree: {}".format(items[-1][0]))
# Out:
# Minimum degree: 1.00
# Maximum degree: 16690.00
# Node ID with maximum degree: 837
# Node ID with minimum degree: 44006

# %% [markdown]
# ## Mall del Sur

# %%
mall_sur = open("./15/mallsurPeso2.csv", 'rb')
mall_sur.readline()
conexiones_mall_sur = nx.read_edgelist(mall_sur, delimiter=',', nodetype=int, data=(('weight',int),))
mall_sur.close()

# %%
degrees_mall_sur = conexiones_mall_sur.degree()

degrees = list(degrees_mall_sur.values())

degrees = sorted(set(degrees))
histogram = [list(degrees_mall_sur.values()).count(x) for x in degrees]

# %%
plt.figure()
plt.plot(degrees, histogram)
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title('Mall del Sur')
plt.savefig("mall_sur_15.png", dpi=500)
plt.show()

# %%
plt.figure()
plt.loglog(degrees,histogram, basex=10, basey=10) # Log Log
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title('Mall del Sur')
plt.savefig("mall_sur_15_pl.png", dpi=500)
plt.show()

# %%
items = list(degrees_mall_sur.items())
items.sort(key=lambda x: x[1], reverse=True)

minimum_degree = items[-1][1]
maximum_degree = items[0][1]

# %%
print("Minimum degree: {:.2f}".format(minimum_degree)) 
print("Maximum degree: {:.2f}".format(maximum_degree))
print("Node ID with maximum degree: {}".format(items[0][0]))
print("Node ID with minimum degree: {}".format(items[-1][0]))
# Out:
# Minimum degree: 1.00
# Maximum degree: 6298.00
# Node ID with maximum degree: 204664
# Node ID with minimum degree: 58552

# %% [markdown]
# ## City Mall

# %%
city_mall = open("./15/citymallPeso2.csv", 'rb')
city_mall.readline()
conexiones_city_mall = nx.read_edgelist(city_mall, delimiter=',', nodetype=int, data=(('weight',int),))
city_mall.close()

# %%
degrees_city_mall = conexiones_city_mall.degree()

degrees = list(degrees_city_mall.values())

degrees = sorted(set(degrees))
histogram = [list(degrees_city_mall.values()).count(x) for x in degrees]

# %%
plt.figure()
plt.plot(degrees, histogram)
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title('City Mall')
plt.savefig("city_mall_15.png", dpi=500)
plt.show()

# %%
plt.figure()
plt.loglog(degrees,histogram, basex=10, basey=10) # Log Log
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title("City Mall")
plt.savefig("city_mall_15_pl.png", dpi=500)
plt.show()

# %%
items = list(degrees_city_mall.items())
items.sort(key=lambda x: x[1], reverse=True)

minimum_degree = items[-1][1]
maximum_degree = items[0][1]

# %%
print("Minimum degree: {:.2f}".format(minimum_degree)) 
print("Maximum degree: {:.2f}".format(maximum_degree))
print("Node ID with maximum degree: {}".format(items[0][0]))
print("Node ID with minimum degree: {}".format(items[-1][0]))
# Out:
# Minimum degree: 1.00
# Maximum degree: 3731.00
# Node ID with maximum degree: 173691
# Node ID with minimum degree: 176794

# %% [markdown]
# ## Todos

# %%
todo = open("./15/todoPeso2.csv", 'rb')
todo.readline()
conexiones_todo = nx.read_edgelist(todo, delimiter=',', nodetype=int, data=(('weight',int),))
todo.close()

# %%
degrees_todo = conexiones_todo.degree()

degrees = list(degrees_todo.values())

degrees = sorted(set(degrees))
histogram = [list(degrees_todo.values()).count(x) for x in degrees]

# %%
plt.figure()
plt.plot(degrees, histogram)
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title('Todo')
plt.savefig("todo_15.png", dpi=500)
plt.show()

# %%
plt.figure()
plt.loglog(degrees,histogram, basex=10, basey=10) # Log Log
plt.xlabel('Degree')
plt.ylabel('Number of nodes')
plt.title("Todo")
plt.savefig("todo_15_pl.png", dpi=500)
plt.show()

# %%
items = list(degrees_todo.items())
items.sort(key=lambda x: x[1], reverse=True)

minimum_degree = items[-1][1]
maximum_degree = items[0][1]

# %%
print("Minimum degree: {:.2f}".format(minimum_degree)) 
print("Maximum degree: {:.2f}".format(maximum_degree))
print("Node ID with maximum degree: {}".format(items[0][0]))
print("Node ID with minimum degree: {}".format(items[-1][0]))
# Out:
# Minimum degree: 1.00
# Maximum degree: 16691.00
# Node ID with maximum degree: 837
# Node ID with minimum degree: 256500
