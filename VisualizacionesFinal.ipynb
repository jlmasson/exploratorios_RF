# %% [markdown]
# # PROYECTO PARCIAL DE ANALISIS EXPLORATORIO DE DATOS

# %% [markdown]
# ## Importaciones

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Carga de DataSets

# %% [markdown]
# En esta parte cargamos los datasets y añadimos las columnas extras necesarias:
#   - conexiones --> dataset_final.csv
#   - sitios --> ma_sitios.csv  --> Añadir columna de ubicacion basada en su latitud y longitud

# %% [markdown]
# ###    Conexiones(Carga y Procesamiento)

# %%
conexiones = pd.DataFrame.from_csv("dataset_final.csv", sep = ",")
conexiones.head(3)
# Out:
#               datetime  codigo  pauta_id  sitio_id            mac_usr  \
# 0  2015-05-15 20:16:35       1        11         2  94:01:C2:97:96:CB
# 1  2015-05-15 20:18:15       2         5         2  8C:BF:A6:17:60:A0
# 2  2015-05-15 20:18:24       3        19         3  74:AA:FE:A5:7E:90
#
#    ip_local      ip_usr       so navegador                 url_ref  \
# 0  10.5.8.1  10.5.10.95  Android    SAFARI  http://10.5.8.1/status
# 1  10.5.8.1   10.5.9.24  Android    CHROME  http://10.5.8.1/status
# 2  10.5.0.1  10.5.0.176  Android    CHROME  http://10.5.0.1/status
#
#   tiempo_espera       fabricante-dispositivo
# 0      00:00:00  Samsung Electronics Co.,Ltd
# 1      00:00:00  Samsung Electronics Co.,Ltd
# 2      00:00:00                          NaN

# %% [markdown]
# Se necesita parsear la columna datatime al formato correcto, y separaremos los valores en varias columnas

# %%
conexiones["datetime"] = pd.to_datetime(conexiones["datetime"])
conexiones["mes"] = conexiones["datetime"].dt.month
conexiones["año"] = conexiones["datetime"].dt.year
conexiones["hora"] = conexiones["datetime"].dt.hour
conexiones["fecha"] = conexiones["datetime"].dt.date
conexiones["weekday"] = conexiones["datetime"].dt.weekday
conexiones.head(2)
# Out:
#              datetime  codigo  pauta_id  sitio_id            mac_usr  \
# 0 2015-05-15 20:16:35       1        11         2  94:01:C2:97:96:CB
# 1 2015-05-15 20:18:15       2         5         2  8C:BF:A6:17:60:A0
#
#    ip_local      ip_usr       so navegador                 url_ref  \
# 0  10.5.8.1  10.5.10.95  Android    SAFARI  http://10.5.8.1/status
# 1  10.5.8.1   10.5.9.24  Android    CHROME  http://10.5.8.1/status
#
#   tiempo_espera       fabricante-dispositivo  mes   año  hora       fecha  \
# 0      00:00:00  Samsung Electronics Co.,Ltd    5  2015    20  2015-05-15
# 1      00:00:00  Samsung Electronics Co.,Ltd    5  2015    20  2015-05-15
#
#    weekday
# 0        4
# 1        4

# %% [markdown]
# Analizaremos algunos de los valores para ver que tenemos, en este caso, so, navegador y fabricante-dispositivo, seran objeto del analisis.

# %% [markdown]
# ## SO

# %%
conexiones["so"].value_counts()
# Out:
# Android          460233
# iPhone           249829
# iPad              14915
# Nokia             13585
# BlackBerry        10804
# Windows10          6731
# Windows7           6122
# Mac                5947
# Windows 8          5489
# Windows 7          4785
# Windows8           3118
# Mac OS X           1974
# WindowsXP          1071
# Linux               461
# WindowsV            165
# Windows 10          136
# Windows XP          111
# Windows Vista        24
# WindowsServer         4
# Name: so, dtype: int64

# %% [markdown]
# Podemos observar que existen valores que podemos englobar en uno solo, para un mejor analisis.

# %% [markdown]
# ### Categorizar SO

# %%
def clasificadorSO(so):
    try:
        if so.lower().startswith("windows"):
            return "Windows"
        if so.lower() == "android":
            return "ANDROID"
        if so.lower() == "ipad" or so.lower() == "iphone" or so.lower() == "ios" or so.lower() == "mac" or so.lower() == "mac os x":
            return "iOS"
        if so.lower() == "linux":
            return "Other"
        return so
    except:
        return "Other"

# %%
conexiones["so"]  = conexiones["so"].apply(lambda x: clasificadorSO(x))
conexiones["so"].value_counts()
# Out:
# ANDROID       460233
# iOS           272665
# Windows        27756
# Nokia          13585
# Other          12826
# BlackBerry     10804
# Name: so, dtype: int64

# %% [markdown]
# # Navegador

# %%
conexiones["navegador"].value_counts()
# Out:
# CHROME     373153
# OTROS      166539
# SAFARI     154120
# OTHER       85851
# IE           9551
# FIREFOX      8641
# OPERA          10
# MOZILLA         4
# Name: navegador, dtype: int64

# %% [markdown]
# Podemos observar que Other y Otros se refieren a lo mismo por lo tanto no deberia existir distincion.

# %% [markdown]
# ### Categorizar Navegador

# %%
def clasificadorNavegador(navegador):
    try:
        if str(navegador.lower()) == "otros" or str(navegador.lower()) == "mozilla" or str(navegador.lower()) == "opera":
            return "OTHER"
        return navegador
    except:
        return "OTHER"

# %%
conexiones["navegador"] = conexiones["navegador"].apply(lambda x: clasificadorNavegador(x))
conexiones["navegador"].value_counts()
# Out:
# CHROME     373153
# OTHER      252404
# SAFARI     154120
# IE           9551
# FIREFOX      8641
# Name: navegador, dtype: int64

# %% [markdown]
# ## Fabricante

# %%
conexiones["fabricante-dispositivo"].value_counts()
# Out:
# Apple                                         162076
# Samsung Electronics Co.,Ltd                   146351
# Sony Mobile Communications AB                  30163
# Samsung Electro Mechanics co., LTD.            27688
# LG Electronics                                 27366
# Nokia Corporation                              19748
# Samsung Elec Co.,Ltd                           17908
# Apple, Inc.                                    17630
# Huawei Technologies Co., Ltd                   17333
# Microsoft Corporation                          16847
# Murata Manufactuaring Co.,Ltd.                 13348
# Samsung Electro Mechanics co.,LTD.             11389
# Motorola Mobility LLC                          10840
# Apple Inc                                      10020
# Research In Motion                              9721
# Apple, Inc                                      9467
# Hon Hai Precision Ind. Co.,Ltd.                 9096
# InPro Comm                                      9004
# WISOL                                           8577
# Intel Corporate                                 8407
# Murata Manufacturing Co., Ltd.                  7766
# Murata Manufacturing Co.,Ltd.                   6617
# Liteon Technology Corporation                   6347
# SAMSUNG ELECTRO MECHANICS CO., LTD.             5827
# TCT Mobile Limited                              5186
# TCT mobile ltd                                  4880
# RIM                                             4872
# Samsung Electronics                             4738
# HTC Corporation                                 4682
# MediaTek Inc.                                   4189
#                                                ...
# FORTUNE TECHGROUP CO.,LTD                          1
# INFORMATION RESOURCE ENGINEERING                   1
# Bookeen                                            1
# ViewSonic Corporation                              1
# M.C.C.I                                            1
# Fiberblaze A/S                                     1
# SANTERA SYSTEMS, INC.                              1
# Tommy Technologies Corp.                           1
# TELDIX GmbH                                        1
# Lumigon A/S                                        1
# I-TEC Co., Ltd.                                    1
# XIAMEN MEITU MOBILE TECHNOLOGY CO.LTD              1
# Emerging Technologies Limited                      1
# Vestel Komunikasyon Sanayi ve Ticaret A.S.         1
# TeraForce Technology Corporation                   1
# Hitachi Denshi, Ltd.                               1
# Intel Corp                                         1
# SMP                                                1
# Pharos Systems NZ                                  1
# embedded-logic DESIGN AND MORE GmbH                1
# TechFaith Wireless Technology Limited              1
# CC&C Technologies, Inc.                            1
# Integrated Network Corporation                     1
# BYD Precision Manufacture Co.,Ltd                  1
# Rancho Technology, Inc.                            1
# Proware Technologies Co Ltd.                       1
# Intersoft Electronics                              1
# VDSL Systems OY                                    1
# XPEED, INC.                                        1
# LG Innotek                                         1
# Name: fabricante-dispositivo, Length: 412, dtype: int64

# %% [markdown]
# Se procedio a analizar en su totalidad todos los fabricantes y se tomo la decision en primera instancia obtener las dos primeras palabras de su nombre y ponerlas totalmente en mayusculas para ver el cambio.

# %% [markdown]
# ## Clasificar Fabricantes

# %%
def clasificarFabricantes(fabricante):
    try:
        fabricante = fabricante.replace(",","")
        fabricante = fabricante.replace(".","")
        fabricante = fabricante.replace("_","")
        fabricante = fabricante.replace("-","")
        palabras = fabricante.upper().split(" ")
        return palabras[0]
    except:
        return "OTHER"

# %%
prueba = conexiones.copy()
prueba["fab2"] = prueba["fabricante-dispositivo"].apply(lambda x: clasificarFabricantes(x))
prueba["fab2"].value_counts()
# Out:
# SAMSUNG          219638
# APPLE            199193
# OTHER            113379
# LG                31348
# SONY              30274
# MURATA            27731
# NOKIA             19901
# HUAWEI            17441
# MICROSOFT         17267
# MOTOROLA          12900
# RESEARCH          12506
# TCT               12409
# HON                9430
# INPRO              9004
# WISOL              8577
# INTEL              8409
# LITEON             6589
# RIM                4875
# HTC                4682
# MEDIATEK           4350
# ZTE                2869
# HONGKONG           1532
# TRENDNET           1512
# GUANGZHOU          1389
# DLINK              1376
# CONSENTRY          1310
# SHENZHEN            966
# ARIMA               954
# TINNO               892
# ASKEY               885
#                   ...
# TECHFAITH             1
# INFORMATION           1
# NEOKOROS              1
# VESTEL                1
# TOMMY                 1
# SANTERA               1
# OCEAN                 1
# WATANABE              1
# POWERFILE             1
# DATACARD              1
# ABATRON               1
# VIVACE                1
# SIMPLE                1
# ROSEMOUNT             1
# RANCHO                1
# EMBEDDEDLOGIC         1
# TELDIX                1
# VIEWSONIC             1
# INTERSOFT             1
# VDSL                  1
# ACN                   1
# MECALC                1
# PROWARE               1
# AIR                   1
# LUMIGON               1
# DALIAN                1
# FORTUNE               1
# VIZIO                 1
# MOVITA                1
# SK                    1
# Name: fab2, Length: 274, dtype: int64

# %% [markdown]
# Se pudo ver que se reducieron considerablemente la cantidad de fabricantes, pero siguen siendo muchos, se decidio agrupar los que solo aparecen una vez por lo tanto se mejoro la funcion de clasificarFabricante a una que reciba un diccionario con la cantidad de veces que aparece el fabricante en el dataset

# %%
def clasificarFabricantes2(dic, fabricante):
    if fabricante in dic:
        if dic[fabricante]["cant"] < 10000:
            return "OTHER"
    return fabricante

# %%
prueba2 = prueba.copy()
dic = prueba2["fab2"].value_counts().to_frame("cant").to_dict("index")
prueba2["fab2"] = prueba2["fab2"].apply(lambda x: clasificarFabricantes2(dic, x))
prueba2["fab2"].value_counts()
# Out:
# SAMSUNG      219638
# APPLE        199193
# OTHER        197261
# LG            31348
# SONY          30274
# MURATA        27731
# NOKIA         19901
# HUAWEI        17441
# MICROSOFT     17267
# MOTOROLA      12900
# RESEARCH      12506
# TCT           12409
# Name: fab2, dtype: int64

# %% [markdown]
# Se pudo reducir a 35 fabricantes lo que es un numero más manejable

# %% [markdown]
# ## Ultimos manejos del Dataframe de conexiones

# %%
conexiones = prueba2.copy()
conexiones.head(2)
# Out:
#              datetime  codigo  pauta_id  sitio_id            mac_usr  \
# 0 2015-05-15 20:16:35       1        11         2  94:01:C2:97:96:CB
# 1 2015-05-15 20:18:15       2         5         2  8C:BF:A6:17:60:A0
#
#    ip_local      ip_usr       so navegador                 url_ref  \
# 0  10.5.8.1  10.5.10.95  ANDROID    SAFARI  http://10.5.8.1/status
# 1  10.5.8.1   10.5.9.24  ANDROID    CHROME  http://10.5.8.1/status
#
#   tiempo_espera       fabricante-dispositivo  mes   año  hora       fecha  \
# 0      00:00:00  Samsung Electronics Co.,Ltd    5  2015    20  2015-05-15
# 1      00:00:00  Samsung Electronics Co.,Ltd    5  2015    20  2015-05-15
#
#    weekday     fab2
# 0        4  SAMSUNG
# 1        4  SAMSUNG

# %% [markdown]
# ###  - Quitar Columnas no necesarias en el analisis

# %%
conexionesFinal = conexiones[["datetime","sitio_id", "mac_usr", "so", "navegador", "fabricante-dispositivo", "hora", "weekday", "fecha", "mes", "año", "fab2"]]
conexionesFinal.head(2)
# Out:
#              datetime  sitio_id            mac_usr       so navegador  \
# 0 2015-05-15 20:16:35         2  94:01:C2:97:96:CB  ANDROID    SAFARI
# 1 2015-05-15 20:18:15         2  8C:BF:A6:17:60:A0  ANDROID    CHROME
#
#         fabricante-dispositivo  hora  weekday       fecha  mes   año     fab2
# 0  Samsung Electronics Co.,Ltd    20        4  2015-05-15    5  2015  SAMSUNG
# 1  Samsung Electronics Co.,Ltd    20        4  2015-05-15    5  2015  SAMSUNG

# %% [markdown]
# ## Sitios

# %%
sitios = pd.DataFrame.from_csv("ma_sitios2.csv", sep = ",").reset_index()
sitios.head(3)
# Out:
#    sitio_id         nombre      siglas           ruc     ciudad  \
# 0         1    ALBAN BORJA  ALBAN BORJ  920124541001  Guayaquil
# 1         2  VILLAGE PLAZA       VILLA             0  Guayaquil
# 2         3      CITY MALL     CITY M.             0  Guayaquil
#
#   nombre_ubicacion            contacto                   direccion  \
# 0        Guayaquil  Fabricio Matamoros  Av. Carlos Julio Arosemena
# 1        Guayaquil            Gabriela                 SAMBORONDON
# 2        Guayaquil            Gabriela                    Alborada
#
#                            email   telefono    ...     transparencia  \
# 0  administracion@albanborja.com  923154211    ...                 0
# 1                            NaN        NaN    ...                 0
# 2                            NaN        NaN    ...                 0
#
#    longitud    latitud             ip  puerto                fecha  \
# 0 -2.168677 -79.916769   186.3.137.95     NaN  2016-09-19 13:28:32
# 1 -2.140406 -79.866376   186.3.144.18     NaN  2016-07-20 17:23:50
# 2 -2.140951 -79.911774  186.3.153.140     NaN  2015-12-22 10:21:54
#
#   usuario_modif  bienvenida formulario    router
# 0    fmatamoros           0          0  Mikrotik
# 1    fmatamoros           0          0       NaN
# 2    fmatamoros           0          0       NaN
#
# [3 rows x 23 columns]

# %% [markdown]
# Como vemos contamos con latitud y longitud, para este analisis agregaremos una nueva columna llamada localizacion, en donde nos dara el lugar geografico donde se encuentra.

# %% [markdown]
# ## Localizar Sitios

# %% [markdown]
# Necesitaremos el boundingbox de los lugares el cual lo llamaremos places

# %%
places =[["Urdesa", [[-79.915581,-2.178119], [-79.901204,-2.146938]]],
             ["MallSur", [[-79.902062,-2.232042], [-79.894681,-2.226038]]],
             ["CityMall", [[-79.912663,-2.143936], [-79.905968,-2.137932]]],
             ["AlbanBorja", [[-79.918242,-2.170096], [-79.915066,-2.167523]]],
             ["Samborondon", [[-79.874897,-2.160447], [-79.852066,-2.116704]]],
             ["Aeropuerto", [[-79.886227,-2.152728], [-79.880562,-2.146338]]],
             ["Penias", [[-79.8776014239,-2.1855487464], [-79.873009,-2.175392]]],
             ["Quito", [[-78.586922,-0.395161], [-78.274155,0.021973]]],
             ["CentroConvenciones", [[-79.893479,-2.161755], [-79.883652,-2.154894]]],
             ["HiltonColon", [[-79.8998951912,-2.160929558], [-79.8962903023,-2.1576274229]]],
             ["MallSol", [[-79.8954641819,-2.157053837], [-79.8891341686,-2.1539258197]]],
             ["UniversidadGuayaquil", [[-79.9008607864,-2.1847947751], [-79.8959684372,-2.1791554991]]]
            ]

# %% [markdown]
# Funcion para localizar las coordenadas

# %%
def localizar(row, places):
    longitud = float(row["longitud"])
    latitud = float(row["latitud"])

    for placeName, ubicacion in places:
        SW, NE= ubicacion
        if (latitud <= NE[0] and longitud <=NE[1] and latitud >= SW[0] and longitud >= SW[1]):
            return placeName
    return "No ubicado"

# %%
sitios['localizacion'] = sitios[["longitud", "latitud"]].apply(lambda row: localizar(row, places), axis = 1)
sitios["localizacion"].value_counts()
# Out:
# CentroConvenciones      9
# Urdesa                  8
# Quito                   8
# AlbanBorja              5
# Samborondon             5
# HiltonColon             2
# Penias                  2
# UniversidadGuayaquil    1
# MallSur                 1
# MallSol                 1
# Aeropuerto              1
# CityMall                1
# Name: localizacion, dtype: int64

# %% [markdown]
# ## Ultimos manejos del dataset sitios

# %% [markdown]
# ###       - Quitar columnas no necesarias para el analisis

# %%
sitios = sitios[["sitio_id","nombre", "longitud", "latitud", "localizacion"]]
sitios.head(3)
# Out:
#    sitio_id         nombre  longitud    latitud localizacion
# 0         1    ALBAN BORJA -2.168677 -79.916769   AlbanBorja
# 1         2  VILLAGE PLAZA -2.140406 -79.866376  Samborondon
# 2         3      CITY MALL -2.140951 -79.911774     CityMall

# %% [markdown]
# # UNIENDO LOS DATAFRAMES

# %%
datos = pd.merge(conexionesFinal, sitios, on = "sitio_id")
datos["hora"] = datos["hora"].apply(lambda x: str(x).rjust(2,"0") + "h")
datos.head(3)
# Out:
#              datetime  sitio_id            mac_usr       so navegador  \
# 0 2015-05-15 20:16:35         2  94:01:C2:97:96:CB  ANDROID    SAFARI
# 1 2015-05-15 20:18:15         2  8C:BF:A6:17:60:A0  ANDROID    CHROME
# 2 2015-05-15 20:20:20         2  34:BE:00:05:16:18  ANDROID    SAFARI
#
#         fabricante-dispositivo hora  weekday       fecha  mes   año     fab2  \
# 0  Samsung Electronics Co.,Ltd  20h        4  2015-05-15    5  2015  SAMSUNG
# 1  Samsung Electronics Co.,Ltd  20h        4  2015-05-15    5  2015  SAMSUNG
# 2  Samsung Electronics Co.,Ltd  20h        4  2015-05-15    5  2015  SAMSUNG
#
#           nombre  longitud    latitud localizacion
# 0  VILLAGE PLAZA -2.140406 -79.866376  Samborondon
# 1  VILLAGE PLAZA -2.140406 -79.866376  Samborondon
# 2  VILLAGE PLAZA -2.140406 -79.866376  Samborondon

# %% [markdown]
# # ANALISIS #1.- Cantidad de Usuarios conectados por hora en un día

# %% [markdown]
# Necesitaremos la franja_horaria, la fecha, localizacion, mac_usr

# %%
dataAnalisis1 = datos.copy()[["fecha", "hora", "localizacion", "mac_usr"]]
dataAnalisis1.head(2)
# Out:
#         fecha hora localizacion            mac_usr
# 0  2015-05-15  20h  Samborondon  94:01:C2:97:96:CB
# 1  2015-05-15  20h  Samborondon  8C:BF:A6:17:60:A0

# %%
dataAnalisis1_Agrup = dataAnalisis1.groupby(["fecha", "hora", "localizacion"]).size().rename("cant_conexiones")
dataAnalisis1_Agrup
# Out:
# fecha       hora  localizacion
# 2015-05-15  20h   CityMall         11
#                   Samborondon      21
#             21h   AlbanBorja        2
#                   CityMall         13
#                   Samborondon      27
#             22h   CityMall          6
#                   Samborondon       8
#             23h   CityMall          1
#                   Quito             3
#                   Samborondon       4
# 2015-05-16  00h   CityMall          1
#                   Samborondon       2
#             02h   Quito             2
#             03h   Quito             2
#             08h   Samborondon       3
#             09h   Samborondon       1
#             10h   AlbanBorja        2
#                   CityMall          3
#                   Samborondon       5
#             11h   AlbanBorja        6
#                   CityMall         14
#                   Samborondon      19
#             12h   AlbanBorja        4
#                   CityMall         20
#                   Samborondon      28
#             13h   AlbanBorja        2
#                   CityMall         21
#                   Samborondon      40
#             14h   AlbanBorja        3
#                   CityMall         20
#                                  ...
# 2016-09-26  13h   Aeropuerto      117
#                   AlbanBorja        2
#             14h   Aeropuerto       73
#             15h   Aeropuerto       78
#             16h   Aeropuerto      129
#             17h   Aeropuerto      208
#             18h   Aeropuerto       70
#             19h   Aeropuerto       76
#             20h   Aeropuerto       61
#             21h   Aeropuerto       64
#             22h   Aeropuerto       61
#             23h   Aeropuerto       31
# 2016-09-27  00h   Aeropuerto       29
#             01h   Aeropuerto       16
#             02h   Aeropuerto       13
#             03h   Aeropuerto       26
#             04h   Aeropuerto       42
#             05h   Aeropuerto       88
#             06h   Aeropuerto       49
#             07h   Aeropuerto       72
#             08h   Aeropuerto       89
#             09h   Aeropuerto       58
#             10h   Aeropuerto       58
#             11h   Aeropuerto       85
#             12h   Aeropuerto       46
#             13h   Aeropuerto       59
#             14h   Aeropuerto       64
#             15h   Aeropuerto       75
#             16h   Aeropuerto      128
#             17h   Aeropuerto      173
# Name: cant_conexiones, Length: 35787, dtype: int64

# %% [markdown]
# ## Analisis general sin diferenciar la localizacion

# %%
dataAnalisis1_1 = dataAnalisis1_Agrup.reset_index()
dataAnalisis1_1 = dataAnalisis1_1.groupby(["fecha", "hora"]).sum()
dataAnalisis1_1
# Out:
#                  cant_conexiones
# fecha      hora
# 2015-05-15 20h                32
#            21h                42
#            22h                14
#            23h                 8
# 2015-05-16 00h                 3
#            02h                 2
#            03h                 2
#            08h                 3
#            09h                 1
#            10h                10
#            11h                39
#            12h                52
#            13h                63
#            14h                59
#            15h                80
#            16h                61
#            17h                53
#            18h                56
#            19h                38
#            20h                47
#            21h                49
#            22h                32
#            23h                 8
# 2015-05-17 00h                 7
#            01h                 3
#            02h                 4
#            03h                 2
#            04h                 1
#            07h                 1
#            09h                 2
# ...                          ...
# 2016-09-26 12h                71
#            13h               119
#            14h                73
#            15h                78
#            16h               129
#            17h               208
#            18h                70
#            19h                76
#            20h                61
#            21h                64
#            22h                61
#            23h                31
# 2016-09-27 00h                29
#            01h                16
#            02h                13
#            03h                26
#            04h                42
#            05h                88
#            06h                49
#            07h                72
#            08h                89
#            09h                58
#            10h                58
#            11h                85
#            12h                46
#            13h                59
#            14h                64
#            15h                75
#            16h               128
#            17h               173
#
# [11143 rows x 1 columns]

# %% [markdown]
# Sacando promedio de conexiones entre dias para cada franja horaria

# %%
dataAnalisis1_1 = dataAnalisis1_1.groupby(["hora"]).mean().add_prefix("mean_")
dataAnalisis1_1
# Out:
#       mean_cant_conexiones
# hora
# 00h              30.535865
# 01h              23.074661
# 02h              14.997579
# 03h              19.200000
# 04h              27.437158
# 05h              41.046512
# 06h              36.701531
# 07h              40.286031
# 08h              47.842975
# 09h              59.143149
# 10h              69.613821
# 11h              86.094070
# 12h              92.000000
# 13h             105.022403
# 14h             106.955375
# 15h             110.087221
# 16h             126.549495
# 17h             142.240404
# 18h             110.432049
# 19h             102.965587
# 20h              88.746450
# 21h              78.807302
# 22h              58.417850
# 23h              42.331967

# %% [markdown]
# ### GRAFICANDO

# %%
sns.set(font_scale=1.5)
g = sns.factorplot(x="hora", y="mean_cant_conexiones", data=dataAnalisis1_1.reset_index(), color = "Green", size=6, aspect=1.5)
plt.xticks(rotation=90)
plt.xlabel("Horas")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio por dias al pasar las horas") 
plt.show()

# %% [markdown]
# ## Analisis en base de la localizacion

# %%
dataLocalizacion =dataAnalisis1_Agrup.reset_index().copy()
def sacarMes(fecha):
    aux = str(fecha).split("-")
    return "-".join(aux[:2])

dataLocalizacion["mes"] = dataLocalizacion["fecha"].apply(lambda x: sacarMes(x))
dataLocalizacion = dataLocalizacion.groupby(["mes", "localizacion"]).sum().reset_index()
dataLocalizacion= dataLocalizacion.groupby("localizacion").mean().add_prefix("mean_")
dataLocalizacion = dataLocalizacion.reset_index().sort_values("mean_cant_conexiones", ascending = False).reset_index()
dataLocalizacion
# Out:
#     index          localizacion  mean_cant_conexiones
# 0       0            Aeropuerto          49237.000000
# 1       6               MallSur          15154.833333
# 2       3              CityMall          14407.833333
# 3       2    CentroConvenciones          11995.666667
# 4       9           Samborondon           5214.307692
# 5      11                Urdesa           2244.545455
# 6       5               MallSol           1849.750000
# 7       1            AlbanBorja           1460.294118
# 8       7                Penias            738.142857
# 9       4           HiltonColon            646.000000
# 10     10  UniversidadGuayaquil            541.166667
# 11      8                 Quito            483.125000

# %% [markdown]
# ## Graficando

# %%
sns.set(font_scale=1.4)
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="localizacion", y="mean_cant_conexiones", data=dataLocalizacion, color = cm(240), size=6, aspect=1.5, kind = "bar")
plt.xticks(rotation=75)
plt.xlabel("Localizacion")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un mes en los distintos lugares") 
plt.show()

# %% [markdown]
# ### Agrupando lugares de pocas conexiones al mes

# %% [markdown]
# Existen muchas localizaciones, se ha decidio mantener el top#5 y agregar una nueva categoria llamada OTHER a el resto de lugares.

# %%
top5 = dataLocalizacion[0:5].set_index("localizacion").to_dict("index")
top5
# Out:
# {'Aeropuerto': {'index': 0.0, 'mean_cant_conexiones': 49237.0},
#  'CentroConvenciones': {'index': 2.0,
#   'mean_cant_conexiones': 11995.666666666666},
#  'CityMall': {'index': 3.0, 'mean_cant_conexiones': 14407.833333333334},
#  'MallSur': {'index': 6.0, 'mean_cant_conexiones': 15154.833333333334},
#  'Samborondon': {'index': 9.0, 'mean_cant_conexiones': 5214.3076923076924}}

# %%
def FiltrarLugares(top5, lugar):
    if lugar not in top5:
        return "OTHER"
    return lugar

# %%
dataLocalizacionFiltrada= dataLocalizacion.copy()
dataLocalizacionFiltrada["localizacion_filtrada"] = dataLocalizacionFiltrada["localizacion"].apply(lambda x: FiltrarLugares(top5, x))
dataLocalizacionFiltrada = dataLocalizacionFiltrada.groupby("localizacion_filtrada").sum().reset_index()
dataLocalizacionFiltrada = dataLocalizacionFiltrada.sort_values("mean_cant_conexiones", ascending = False).reset_index()
dataLocalizacionFiltrada
# Out:
#    level_0 localizacion_filtrada  index  mean_cant_conexiones
# 0        0            Aeropuerto      0          49237.000000
# 1        3               MallSur      6          15154.833333
# 2        2              CityMall      3          14407.833333
# 3        1    CentroConvenciones      2          11995.666667
# 4        4                 OTHER     46           7963.024096
# 5        5           Samborondon      9           5214.307692

# %%
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="localizacion_filtrada", y="mean_cant_conexiones", data=dataLocalizacionFiltrada, color = cm(20), size=6, aspect=1.5, kind = "bar")
plt.xticks(rotation=75)
plt.xlabel("Localizacion")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un mes en los distintos lugares-Filtrado") 
plt.show()

# %% [markdown]
# ## Analisis especifico diferenciando por localizaciones

# %%
dataAnalisis1_2 = dataAnalisis1.copy()
dataAnalisis1_2["localizacion_filtrada"] = dataAnalisis1_2["localizacion"].apply(lambda x: FiltrarLugares(top5, x))
dataAnalisis1_2 = dataAnalisis1_2.groupby(["localizacion_filtrada", "fecha", "hora"]).size().rename("cant_conexiones").reset_index()
dataAnalisis1_2 = dataAnalisis1_2.groupby(["localizacion_filtrada", "hora"]).mean().add_prefix("mean_").reset_index()
dataAnalisis1_2
# Out:
#     localizacion_filtrada hora  mean_cant_conexiones
# 0              Aeropuerto  00h             52.598592
# 1              Aeropuerto  01h             38.241135
# 2              Aeropuerto  02h             22.464789
# 3              Aeropuerto  03h             40.161972
# 4              Aeropuerto  04h             63.387324
# 5              Aeropuerto  05h             93.992958
# 6              Aeropuerto  06h             94.711268
# 7              Aeropuerto  07h            111.633803
# 8              Aeropuerto  08h            113.154930
# 9              Aeropuerto  09h            107.769231
# 10             Aeropuerto  10h             94.104895
# 11             Aeropuerto  11h             84.055944
# 12             Aeropuerto  12h             67.188811
# 13             Aeropuerto  13h             86.741259
# 14             Aeropuerto  14h             70.580420
# 15             Aeropuerto  15h             87.591549
# 16             Aeropuerto  16h            147.859155
# 17             Aeropuerto  17h            197.188811
# 18             Aeropuerto  18h             97.140845
# 19             Aeropuerto  19h             89.471831
# 20             Aeropuerto  20h             73.638298
# 21             Aeropuerto  21h             82.851064
# 22             Aeropuerto  22h             83.443662
# 23             Aeropuerto  23h             77.397163
# 24     CentroConvenciones  00h              8.075758
# 25     CentroConvenciones  01h              6.898678
# 26     CentroConvenciones  02h              5.142132
# 27     CentroConvenciones  03h              4.227273
# 28     CentroConvenciones  04h              3.046784
# 29     CentroConvenciones  05h              2.742690
# ..                    ...  ...                   ...
# 114                 OTHER  18h             13.004728
# 115                 OTHER  19h             13.057279
# 116                 OTHER  20h             11.707317
# 117                 OTHER  21h              9.516049
# 118                 OTHER  22h              9.457766
# 119                 OTHER  23h             11.241692
# 120           Samborondon  00h              2.691429
# 121           Samborondon  01h              2.691667
# 122           Samborondon  02h              2.974026
# 123           Samborondon  03h              2.289474
# 124           Samborondon  04h              1.896552
# 125           Samborondon  05h              1.739130
# 126           Samborondon  06h              1.480000
# 127           Samborondon  07h              1.543478
# 128           Samborondon  08h              2.393939
# 129           Samborondon  09h              3.190972
# 130           Samborondon  10h              6.368078
# 131           Samborondon  11h             11.488746
# 132           Samborondon  12h             14.449686
# 133           Samborondon  13h             17.422360
# 134           Samborondon  14h             20.170732
# 135           Samborondon  15h             20.541796
# 136           Samborondon  16h             19.324074
# 137           Samborondon  17h             18.795666
# 138           Samborondon  18h             18.513678
# 139           Samborondon  19h             16.934985
# 140           Samborondon  20h             15.120370
# 141           Samborondon  21h             13.710611
# 142           Samborondon  22h              6.761905
# 143           Samborondon  23h              3.148760
#
# [144 rows x 3 columns]

# %%
sns.set(font_scale=1.5)
g = sns.factorplot(x="hora", y="mean_cant_conexiones", data=dataAnalisis1_2, size=6, aspect=1.5, hue = "localizacion_filtrada")
plt.xticks(rotation=0)
plt.xlabel("Horas")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un dia al pasar las horas") 
plt.show()

# %%
dataUnif = pd.merge(dataAnalisis1_1.reset_index().rename(columns={'hora': 'hora', 'mean_cant_conexiones': 'TODOS'}),
                    dataAnalisis1_2.pivot(index='hora', columns='localizacion_filtrada', values='mean_cant_conexiones').reset_index(),
                    on = "hora")
dataUnif = pd.melt(dataUnif, id_vars=['hora'], var_name='localizacion_filtrada', value_name='mean_cant_conexiones')
dataUnif
# Out:
#     hora localizacion_filtrada  mean_cant_conexiones
# 0    00h                 TODOS             30.535865
# 1    01h                 TODOS             23.074661
# 2    02h                 TODOS             14.997579
# 3    03h                 TODOS             19.200000
# 4    04h                 TODOS             27.437158
# 5    05h                 TODOS             41.046512
# 6    06h                 TODOS             36.701531
# 7    07h                 TODOS             40.286031
# 8    08h                 TODOS             47.842975
# 9    09h                 TODOS             59.143149
# 10   10h                 TODOS             69.613821
# 11   11h                 TODOS             86.094070
# 12   12h                 TODOS             92.000000
# 13   13h                 TODOS            105.022403
# 14   14h                 TODOS            106.955375
# 15   15h                 TODOS            110.087221
# 16   16h                 TODOS            126.549495
# 17   17h                 TODOS            142.240404
# 18   18h                 TODOS            110.432049
# 19   19h                 TODOS            102.965587
# 20   20h                 TODOS             88.746450
# 21   21h                 TODOS             78.807302
# 22   22h                 TODOS             58.417850
# 23   23h                 TODOS             42.331967
# 24   00h            Aeropuerto             52.598592
# 25   01h            Aeropuerto             38.241135
# 26   02h            Aeropuerto             22.464789
# 27   03h            Aeropuerto             40.161972
# 28   04h            Aeropuerto             63.387324
# 29   05h            Aeropuerto             93.992958
# ..   ...                   ...                   ...
# 138  18h                 OTHER             13.004728
# 139  19h                 OTHER             13.057279
# 140  20h                 OTHER             11.707317
# 141  21h                 OTHER              9.516049
# 142  22h                 OTHER              9.457766
# 143  23h                 OTHER             11.241692
# 144  00h           Samborondon              2.691429
# 145  01h           Samborondon              2.691667
# 146  02h           Samborondon              2.974026
# 147  03h           Samborondon              2.289474
# 148  04h           Samborondon              1.896552
# 149  05h           Samborondon              1.739130
# 150  06h           Samborondon              1.480000
# 151  07h           Samborondon              1.543478
# 152  08h           Samborondon              2.393939
# 153  09h           Samborondon              3.190972
# 154  10h           Samborondon              6.368078
# 155  11h           Samborondon             11.488746
# 156  12h           Samborondon             14.449686
# 157  13h           Samborondon             17.422360
# 158  14h           Samborondon             20.170732
# 159  15h           Samborondon             20.541796
# 160  16h           Samborondon             19.324074
# 161  17h           Samborondon             18.795666
# 162  18h           Samborondon             18.513678
# 163  19h           Samborondon             16.934985
# 164  20h           Samborondon             15.120370
# 165  21h           Samborondon             13.710611
# 166  22h           Samborondon              6.761905
# 167  23h           Samborondon              3.148760
#
# [168 rows x 3 columns]

# %%
sns.set(font_scale=1.5)
g = sns.factorplot(x="hora", y="mean_cant_conexiones", data=dataUnif, size=7.5, aspect=1.6, hue = "localizacion_filtrada", palette = sns.hls_palette(8, l=.3, s=.8))
plt.xticks(rotation=90)
plt.xlabel("Horas", color = "Blue", size = 30)
plt.ylabel("# Conexiones", color = "Blue", size = 30)
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un dia al pasar las horas", color = "RED", size = 28) 
plt.show()

# %% [markdown]
# # ANALISIS #2.- Cantidad de Usuarios conectados en un mes por su SO, Navegador y Fabricante

# %%
dataAnalisis2 = datos.copy()[["fecha", "localizacion", "mac_usr", "so", "navegador", "fab2"]]
dataAnalisis2["mes"] = dataAnalisis2["fecha"].apply(lambda x: sacarMes(x))
dataAnalisis2["localizacion_filtrada"] = dataAnalisis2["localizacion"].apply(lambda x: FiltrarLugares(top5, x))

dataAnalisis2.head(2)
# Out:
#         fecha localizacion            mac_usr       so navegador     fab2  \
# 0  2015-05-15  Samborondon  94:01:C2:97:96:CB  ANDROID    SAFARI  SAMSUNG
# 1  2015-05-15  Samborondon  8C:BF:A6:17:60:A0  ANDROID    CHROME  SAMSUNG
#
#        mes localizacion_filtrada
# 0  2015-05           Samborondon
# 1  2015-05           Samborondon

# %% [markdown]
# ## -SO

# %%
dataAnalisis2SO = dataAnalisis2.groupby(["mes","so"]).size().rename("cant_conexiones").reset_index()
dataAnalisis2SO = dataAnalisis2SO.groupby(["so"]).mean().add_prefix("mean_").reset_index()
dataAnalisis2SO = dataAnalisis2SO.sort_values("mean_cant_conexiones", ascending = False).reset_index()
dataAnalisis2SO
# Out:
#    index          so  mean_cant_conexiones
# 0      0     ANDROID          27066.647059
# 1      5         iOS          16039.000000
# 2      4     Windows           1632.588235
# 3      2       Nokia            799.058824
# 4      3       Other            754.294118
# 5      1  BlackBerry            635.294118

# %%
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="so", y="mean_cant_conexiones", data=dataAnalisis2SO, color = cm(200), size=6, aspect=1.5, kind = "bar")
plt.xticks(rotation=75)
plt.xlabel("SO")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un mes por SO") 
plt.show()

# %%
dataAnalisis2SOLocalizacion = dataAnalisis2.groupby(["localizacion_filtrada","mes","so"]).size().rename("cant_conexiones").reset_index()
dataAnalisis2SOLocalizacion = dataAnalisis2SOLocalizacion.groupby(["localizacion_filtrada","so"]).mean().add_prefix("mean_").reset_index()
dataAnalisis2SOLocalizacion = dataAnalisis2SOLocalizacion.sort_values(["localizacion_filtrada","mean_cant_conexiones"], ascending = [True,False]).reset_index()
dataAnalisis2SOLocalizacion
# Out:
#     index localizacion_filtrada          so  mean_cant_conexiones
# 0       5            Aeropuerto         iOS          25176.500000
# 1       0            Aeropuerto     ANDROID          21486.666667
# 2       4            Aeropuerto     Windows           2072.000000
# 3       2            Aeropuerto       Nokia            221.833333
# 4       3            Aeropuerto       Other            211.166667
# 5       1            Aeropuerto  BlackBerry             68.833333
# 6       6    CentroConvenciones     ANDROID           7006.200000
# 7      11    CentroConvenciones         iOS           4046.466667
# 8      10    CentroConvenciones     Windows            495.933333
# 9       9    CentroConvenciones       Other            287.600000
# 10      8    CentroConvenciones       Nokia             90.357143
# 11      7    CentroConvenciones  BlackBerry             86.692308
# 12     12              CityMall     ANDROID          10439.166667
# 13     17              CityMall         iOS           2067.833333
# 14     14              CityMall       Nokia            638.166667
# 15     13              CityMall  BlackBerry            455.666667
# 16     16              CityMall     Windows            406.666667
# 17     15              CityMall       Other            400.333333
# 18     18               MallSur     ANDROID          11541.333333
# 19     23               MallSur         iOS           1874.833333
# 20     20               MallSur       Nokia            736.666667
# 21     19               MallSur  BlackBerry            463.666667
# 22     21               MallSur       Other            370.833333
# 23     22               MallSur     Windows            201.000000
# 24     24                 OTHER     ANDROID           3006.647059
# 25     29                 OTHER         iOS           1019.529412
# 26     28                 OTHER     Windows            199.588235
# 27     25                 OTHER  BlackBerry            184.400000
# 28     26                 OTHER       Nokia            109.733333
# 29     27                 OTHER       Other             58.117647
# 30     30           Samborondon     ANDROID           3317.230769
# 31     35           Samborondon         iOS           1532.230769
# 32     33           Samborondon       Other            125.153846
# 33     32           Samborondon       Nokia             91.083333
# 34     31           Samborondon  BlackBerry             88.909091
# 35     34           Samborondon     Windows             87.083333

# %%
sns.set(font_scale=2)
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="localizacion_filtrada", y="mean_cant_conexiones", data=dataAnalisis2SOLocalizacion, size=12, aspect=1.5, kind = "bar", hue = "so")
plt.xticks(rotation=20)
plt.xlabel("Localizacion")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un mes por SO") 
plt.show()

# %% [markdown]
# ## -Navegador

# %%
dataAnalisis2Nav = dataAnalisis2.groupby(["mes","navegador"]).size().rename("cant_conexiones").reset_index()
dataAnalisis2Nav = dataAnalisis2Nav.groupby(["navegador"]).mean().add_prefix("mean_").reset_index()
dataAnalisis2Nav = dataAnalisis2Nav.sort_values("mean_cant_conexiones", ascending = False).reset_index()
dataAnalisis2Nav
# Out:
#    index navegador  mean_cant_conexiones
# 0      0    CHROME          21947.352941
# 1      3     OTHER          14847.117647
# 2      4    SAFARI           9062.588235
# 3      2        IE            561.705882
# 4      1   FIREFOX            508.117647

# %%
sns.set(font_scale=1.5)
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="navegador", y="mean_cant_conexiones", data=dataAnalisis2Nav, color = "Cyan", size=5, aspect=1.5, kind = "bar")
plt.xticks(rotation=30)
plt.xlabel("SO")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un mes por SO") 
plt.show()

# %%
dataAnalisis2NavLocalizacion = dataAnalisis2.groupby(["localizacion_filtrada","mes","navegador"]).size().rename("cant_conexiones").reset_index()
dataAnalisis2NavLocalizacion = dataAnalisis2NavLocalizacion.groupby(["localizacion_filtrada","navegador"]).mean().add_prefix("mean_").reset_index()
dataAnalisis2NavLocalizacion = dataAnalisis2NavLocalizacion.sort_values(["localizacion_filtrada","mean_cant_conexiones"], ascending = [True,False]).reset_index()
dataAnalisis2NavLocalizacion
# Out:
#     index localizacion_filtrada navegador  mean_cant_conexiones
# 0       3            Aeropuerto     OTHER          24463.166667
# 1       0            Aeropuerto    CHROME          20196.166667
# 2       4            Aeropuerto    SAFARI           3850.000000
# 3       1            Aeropuerto   FIREFOX            480.000000
# 4       2            Aeropuerto        IE            247.666667
# 5       5    CentroConvenciones    CHROME           6183.466667
# 6       8    CentroConvenciones     OTHER           3449.000000
# 7       9    CentroConvenciones    SAFARI           2131.400000
# 8       6    CentroConvenciones   FIREFOX            138.800000
# 9       7    CentroConvenciones        IE             93.000000
# 10     10              CityMall    CHROME           7185.500000
# 11     14              CityMall    SAFARI           4882.500000
# 12     13              CityMall     OTHER           1710.833333
# 13     12              CityMall        IE            420.666667
# 14     11              CityMall   FIREFOX            208.333333
# 15     15               MallSur    CHROME           7632.166667
# 16     19               MallSur    SAFARI           5454.666667
# 17     18               MallSur     OTHER           1495.833333
# 18     17               MallSur        IE            429.666667
# 19     16               MallSur   FIREFOX            142.500000
# 20     20                 OTHER    CHROME           2245.647059
# 21     24                 OTHER    SAFARI           1177.470588
# 22     23                 OTHER     OTHER           1003.764706
# 23     21                 OTHER   FIREFOX             65.235294
# 24     22                 OTHER        IE             58.133333
# 25     25           Samborondon    CHROME           2468.769231
# 26     28           Samborondon     OTHER           1352.538462
# 27     29           Samborondon    SAFARI           1304.076923
# 28     27           Samborondon        IE             57.833333
# 29     26           Samborondon   FIREFOX             35.538462

# %%
sns.set(font_scale=2)
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="localizacion_filtrada", y="mean_cant_conexiones", data=dataAnalisis2NavLocalizacion, size=12, aspect=1.5, kind = "bar", hue = "navegador")
plt.xticks(rotation=20)
plt.xlabel("Localizacion")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un mes por SO") 
plt.show()

# %% [markdown]
# ## -Fabricante

# %%
dataAnalisis2Fab = dataAnalisis2.groupby(["mes","fab2"]).size().rename("cant_conexiones").reset_index()
dataAnalisis2Fab = dataAnalisis2Fab.groupby(["fab2"]).mean().add_prefix("mean_").reset_index()
dataAnalisis2Fab = dataAnalisis2Fab.sort_values("mean_cant_conexiones", ascending = False).reset_index()
dataAnalisis2Fab
# Out:
#     index       fab2  mean_cant_conexiones
# 0       9    SAMSUNG          12916.176471
# 1       0      APPLE          11717.235294
# 2       7      OTHER          11602.058824
# 3       2         LG           1843.588235
# 4      10       SONY           1780.588235
# 5       5     MURATA           1631.000000
# 6       6      NOKIA           1170.588235
# 7       1     HUAWEI           1025.823529
# 8       3  MICROSOFT           1015.705882
# 9       4   MOTOROLA            758.823529
# 10      8   RESEARCH            735.470588
# 11     11        TCT            729.823529

# %%
sns.set(font_scale=1.5)
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="fab2", y="mean_cant_conexiones", data=dataAnalisis2Fab, color = "Pink", size=5, aspect=3.5, kind = "bar")
plt.xticks(rotation=30)
plt.xlabel("Fabricante")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.title("Cantidad de conexiones promedio en un mes por Fabricante") 
plt.show()

# %%
dataAnalisis2FabLocalizacion = dataAnalisis2.groupby(["localizacion_filtrada","mes","fab2"]).size().rename("cant_conexiones").reset_index()
dataAnalisis2FabLocalizacion = dataAnalisis2FabLocalizacion.groupby(["localizacion_filtrada","fab2"]).mean().add_prefix("mean_").reset_index()
dataAnalisis2FabLocalizacion = dataAnalisis2FabLocalizacion.sort_values(["localizacion_filtrada","mean_cant_conexiones"], ascending = [True,False]).reset_index()
dataAnalisis2FabLocalizacion
# Out:
#     index localizacion_filtrada       fab2  mean_cant_conexiones
# 0       7            Aeropuerto      OTHER          18219.833333
# 1       0            Aeropuerto      APPLE          17476.333333
# 2       9            Aeropuerto    SAMSUNG           7650.833333
# 3       5            Aeropuerto     MURATA           1678.833333
# 4      10            Aeropuerto       SONY           1134.333333
# 5       2            Aeropuerto         LG            983.000000
# 6       1            Aeropuerto     HUAWEI            499.333333
# 7       4            Aeropuerto   MOTOROLA            447.666667
# 8       3            Aeropuerto  MICROSOFT            447.500000
# 9       6            Aeropuerto      NOKIA            319.833333
# 10     11            Aeropuerto        TCT            233.333333
# 11      8            Aeropuerto   RESEARCH            146.166667
# 12     21    CentroConvenciones    SAMSUNG           3169.866667
# 13     12    CentroConvenciones      APPLE           3094.800000
# 14     19    CentroConvenciones      OTHER           2642.533333
# 15     22    CentroConvenciones       SONY            552.733333
# 16     14    CentroConvenciones         LG            471.666667
# 17     15    CentroConvenciones  MICROSOFT            424.866667
# 18     17    CentroConvenciones     MURATA            351.600000
# 19     13    CentroConvenciones     HUAWEI            294.866667
# 20     16    CentroConvenciones   MOTOROLA            292.000000
# 21     18    CentroConvenciones      NOKIA            273.866667
# 22     20    CentroConvenciones   RESEARCH            250.066667
# 23     23    CentroConvenciones        TCT            176.800000
# 24     33              CityMall    SAMSUNG           5696.333333
# 25     31              CityMall      OTHER           2155.333333
# 26     24              CityMall      APPLE           1390.166667
# 27     26              CityMall         LG            839.666667
# 28     30              CityMall      NOKIA            783.500000
# 29     34              CityMall       SONY            717.833333
# ..    ...                   ...        ...                   ...
# 42     37               MallSur     HUAWEI            582.333333
# 43     46               MallSur       SONY            560.833333
# 44     39               MallSur  MICROSOFT            484.833333
# 45     47               MallSur        TCT            467.333333
# 46     44               MallSur   RESEARCH            415.166667
# 47     40               MallSur   MOTOROLA            315.166667
# 48     57                 OTHER    SAMSUNG           1666.764706
# 49     48                 OTHER      APPLE            908.294118
# 50     55                 OTHER      OTHER            812.470588
# 51     50                 OTHER         LG            250.764706
# 52     58                 OTHER       SONY            235.823529
# 53     53                 OTHER     MURATA            167.882353
# 54     54                 OTHER      NOKIA            130.812500
# 55     56                 OTHER   RESEARCH            111.062500
# 56     49                 OTHER     HUAWEI            109.000000
# 57     59                 OTHER        TCT             70.823529
# 58     51                 OTHER  MICROSOFT             49.058824
# 59     52                 OTHER   MOTOROLA             44.882353
# 60     69           Samborondon    SAMSUNG           1822.384615
# 61     60           Samborondon      APPLE           1305.692308
# 62     67           Samborondon      OTHER            722.538462
# 63     70           Samborondon       SONY            268.615385
# 64     62           Samborondon         LG            252.769231
# 65     65           Samborondon     MURATA            222.153846
# 66     61           Samborondon     HUAWEI            152.307692
# 67     66           Samborondon      NOKIA            137.384615
# 68     63           Samborondon  MICROSOFT            107.384615
# 69     68           Samborondon   RESEARCH             90.250000
# 70     71           Samborondon        TCT             75.076923
# 71     64           Samborondon   MOTOROLA             64.692308
#
# [72 rows x 4 columns]

# %%
sns.set(font_scale=2)
cm = plt.cm.get_cmap('RdYlBu_r')
g = sns.factorplot(x="fab2", y="mean_cant_conexiones", data=dataAnalisis2FabLocalizacion, size=5, aspect=3.5, kind = "bar", row = "localizacion_filtrada")
plt.xticks(rotation=20)
plt.xlabel("Localizacion")
plt.ylabel("# Conexiones")
plt.grid(True)
plt.show()
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x0C350170>

# %% [markdown]
# # Categorizando a los usuarios en base a que tanto frecuentan las localizaciones en un mes

# %%
dataAnalisis3 = datos.copy()[["fecha", "localizacion", "mac_usr"]]
dataAnalisis3["mes"] = dataAnalisis3["fecha"].apply(lambda x: sacarMes(x))
dataAnalisis3["localizacion_filtrada"] = dataAnalisis3["localizacion"].apply(lambda x: FiltrarLugares(top5, x))
dataAnalisis3.head(3)
# Out:
#         fecha localizacion            mac_usr      mes localizacion_filtrada
# 0  2015-05-15  Samborondon  94:01:C2:97:96:CB  2015-05           Samborondon
# 1  2015-05-15  Samborondon  8C:BF:A6:17:60:A0  2015-05           Samborondon
# 2  2015-05-15  Samborondon  34:BE:00:05:16:18  2015-05           Samborondon

# %%
dataAnalisis3 = dataAnalisis3.groupby(["mes", "localizacion_filtrada", "mac_usr"]).size().rename("cant_conexiones").reset_index()
dataAnalisis3 = dataAnalisis3.groupby(["mac_usr","localizacion_filtrada"]).mean().add_prefix("mean_").reset_index()
dataAnalisis3 =dataAnalisis3.sort_values("mean_cant_conexiones", ascending = False)
dataAnalisis3
# Out:
#                   mac_usr localizacion_filtrada  mean_cant_conexiones
# 6787    00:14:D1:5C:98:CD            Aeropuerto            374.000000
# 231529  D0:92:9E:0F:27:14            Aeropuerto            261.666667
# 56366   2C:D0:5A:72:6D:AA            Aeropuerto            222.400000
# 5628    00:0C:E7:80:B9:97            Aeropuerto            217.500000
# 74630   3C:D0:F8:61:11:09            Aeropuerto            177.000000
# 48838   24:E3:14:85:4D:79            Aeropuerto            171.500000
# 163360  90:94:E4:0A:4B:E6            Aeropuerto            169.500000
# 80091   40:F3:08:37:4B:DB           Samborondon            162.666667
# 237694  D8:EB:97:23:BE:30            Aeropuerto            154.500000
# 217826  C8:14:79:A7:85:EF               MallSur            141.500000
# 42049   1C:E6:2B:43:00:10           Samborondon            136.000000
# 273686  F8:E0:79:EC:61:33    CentroConvenciones            135.000000
# 165737  94:01:C2:CE:F8:21               MallSur            133.500000
# 75086   40:0E:85:15:34:58           Samborondon            133.200000
# 41700   1C:B0:94:75:B9:A9            Aeropuerto            132.000000
# 152256  84:8E:DF:B6:80:4D           Samborondon            130.200000
# 127953  74:45:8A:07:62:A6           Samborondon            128.500000
# 114282  64:B8:53:DF:70:96               MallSur            124.000000
# 46951   24:69:A5:9B:D4:BC               MallSur            123.400000
# 258445  F0:25:B7:51:AB:54           Samborondon            123.100000
# 256003  EC:59:E7:EF:95:16    CentroConvenciones            122.800000
# 213421  C0:D9:62:4E:DE:B9           Samborondon            120.000000
# 105195  5C:E8:EB:CB:9C:10              CityMall            119.500000
# 26525   10:68:3F:94:CA:2C                 OTHER            117.500000
# 64639   34:BB:1F:C8:E3:90                 OTHER            116.500000
# 203874  BC:20:A4:58:B8:97                 OTHER            115.666667
# 77753   40:6F:2A:D5:37:2A    CentroConvenciones            114.666667
# 216858  C4:9A:02:47:37:B7           Samborondon            113.500000
# 83697   44:D4:E0:A3:3E:4A           Samborondon            112.750000
# 204005  BC:25:E0:08:97:2E           Samborondon            111.500000
# ...                   ...                   ...                   ...
# 112454  64:9A:BE:56:3E:41            Aeropuerto              1.000000
# 112455  64:9A:BE:56:7B:F2            Aeropuerto              1.000000
# 112456  64:9A:BE:56:7B:F2                 OTHER              1.000000
# 112411  64:9A:BE:3F:BB:67           Samborondon              1.000000
# 112406  64:9A:BE:3F:05:B1            Aeropuerto              1.000000
# 112357  64:9A:BE:25:0A:15            Aeropuerto              1.000000
# 112386  64:9A:BE:38:51:4E            Aeropuerto              1.000000
# 112364  64:9A:BE:27:F0:52            Aeropuerto              1.000000
# 112365  64:9A:BE:28:F6:BF            Aeropuerto              1.000000
# 112367  64:9A:BE:2B:CF:F9            Aeropuerto              1.000000
# 112368  64:9A:BE:2B:FA:C6            Aeropuerto              1.000000
# 112370  64:9A:BE:2C:6D:64            Aeropuerto              1.000000
# 112374  64:9A:BE:2E:44:2A            Aeropuerto              1.000000
# 112375  64:9A:BE:2E:B9:E0    CentroConvenciones              1.000000
# 112376  64:9A:BE:2E:E3:96            Aeropuerto              1.000000
# 112381  64:9A:BE:34:0F:C2            Aeropuerto              1.000000
# 112383  64:9A:BE:34:A1:00            Aeropuerto              1.000000
# 112387  64:9A:BE:38:B6:BC            Aeropuerto              1.000000
# 112403  64:9A:BE:3E:B5:7B            Aeropuerto              1.000000
# 112390  64:9A:BE:3B:29:D7            Aeropuerto              1.000000
# 112391  64:9A:BE:3B:2B:F5            Aeropuerto              1.000000
# 112392  64:9A:BE:3B:C9:86            Aeropuerto              1.000000
# 112393  64:9A:BE:3C:5A:C5            Aeropuerto              1.000000
# 112394  64:9A:BE:3C:9C:02           Samborondon              1.000000
# 112395  64:9A:BE:3D:39:90            Aeropuerto              1.000000
# 112398  64:9A:BE:3D:C9:DA           Samborondon              1.000000
# 112399  64:9A:BE:3D:D6:4B                 OTHER              1.000000
# 112401  64:9A:BE:3E:7E:8C            Aeropuerto              1.000000
# 112402  64:9A:BE:3E:A4:09            Aeropuerto              1.000000
# 277289  FE:B5:28:8B:F1:9A                 OTHER              1.000000
#
# [277290 rows x 3 columns]

# %%
dataAnalisis3B = dataAnalisis3.pivot(index='mac_usr', columns='localizacion_filtrada', values='mean_cant_conexiones')
dataAnalisis3B = dataAnalisis3B.fillna(0).reset_index()
columnas =list(dataAnalisis3B)
columnas.remove("mac_usr")
dataAnalisis3B['total'] = dataAnalisis3B[columnas].sum(axis=1)
columnasNueva = ["total"]
for c in columnas:
    columnasNueva += [c]
    dataAnalisis3B[c] =(dataAnalisis3B[c]*100)/dataAnalisis3B["total"]
dataAnalisis3B = pd.melt(dataAnalisis3B, id_vars=["mac_usr", "total"], var_name='localizacion', value_name='%Frecuencia')
#dataAnalisis3B.sort_values("total", ascending = False)
dataAnalisis3B.sort_values("mac_usr")
# Out:
#                    mac_usr  total        localizacion  %Frecuencia
# 0        00:00:00:00:90:DC    6.4          Aeropuerto          0.0
# 1039376  00:00:00:00:90:DC    6.4               OTHER          0.0
# 1299220  00:00:00:00:90:DC    6.4         Samborondon        100.0
# 519688   00:00:00:00:90:DC    6.4            CityMall          0.0
# 259844   00:00:00:00:90:DC    6.4  CentroConvenciones          0.0
# 779532   00:00:00:00:90:DC    6.4             MallSur          0.0
# 519689   00:00:02:99:6F:E8    2.0            CityMall          0.0
# 779533   00:00:02:99:6F:E8    2.0             MallSur          0.0
# 259845   00:00:02:99:6F:E8    2.0  CentroConvenciones          0.0
# 1299221  00:00:02:99:6F:E8    2.0         Samborondon          0.0
# 1039377  00:00:02:99:6F:E8    2.0               OTHER          0.0
# 1        00:00:02:99:6F:E8    2.0          Aeropuerto        100.0
# 779534   00:00:3A:CF:68:3A    1.0             MallSur          0.0
# 2        00:00:3A:CF:68:3A    1.0          Aeropuerto        100.0
# 519690   00:00:3A:CF:68:3A    1.0            CityMall          0.0
# 259846   00:00:3A:CF:68:3A    1.0  CentroConvenciones          0.0
# 1039378  00:00:3A:CF:68:3A    1.0               OTHER          0.0
# 1299222  00:00:3A:CF:68:3A    1.0         Samborondon          0.0
# 1039379  00:00:46:0F:20:45    2.5               OTHER          0.0
# 3        00:00:46:0F:20:45    2.5          Aeropuerto          0.0
# 1299223  00:00:46:0F:20:45    2.5         Samborondon          0.0
# 779535   00:00:46:0F:20:45    2.5             MallSur        100.0
# 259847   00:00:46:0F:20:45    2.5  CentroConvenciones          0.0
# 519691   00:00:46:0F:20:45    2.5            CityMall          0.0
# 4        00:00:46:28:CD:BF    2.0          Aeropuerto          0.0
# 779536   00:00:46:28:CD:BF    2.0             MallSur          0.0
# 259848   00:00:46:28:CD:BF    2.0  CentroConvenciones          0.0
# 519692   00:00:46:28:CD:BF    2.0            CityMall        100.0
# 1299224  00:00:46:28:CD:BF    2.0         Samborondon          0.0
# 1039380  00:00:46:28:CD:BF    2.0               OTHER          0.0
# ...                    ...    ...                 ...          ...
# 1559059  FC:FC:48:DA:3B:7A    7.5         Samborondon          0.0
# 259839   FC:FC:48:DA:3B:7A    7.5          Aeropuerto          0.0
# 1039371  FC:FC:48:DA:3B:7A    7.5             MallSur          0.0
# 519683   FC:FC:48:DA:3B:7A    7.5  CentroConvenciones        100.0
# 779527   FC:FC:48:DA:3B:7A    7.5            CityMall          0.0
# 1299215  FC:FC:48:DA:3B:7A    7.5               OTHER          0.0
# 259840   FC:FC:48:DB:A4:2C    2.0          Aeropuerto        100.0
# 519684   FC:FC:48:DB:A4:2C    2.0  CentroConvenciones          0.0
# 779528   FC:FC:48:DB:A4:2C    2.0            CityMall          0.0
# 1039372  FC:FC:48:DB:A4:2C    2.0             MallSur          0.0
# 1299216  FC:FC:48:DB:A4:2C    2.0               OTHER          0.0
# 1559060  FC:FC:48:DB:A4:2C    2.0         Samborondon          0.0
# 519685   FE:00:00:07:69:6D    1.0  CentroConvenciones          0.0
# 779529   FE:00:00:07:69:6D    1.0            CityMall          0.0
# 1559061  FE:00:00:07:69:6D    1.0         Samborondon          0.0
# 259841   FE:00:00:07:69:6D    1.0          Aeropuerto        100.0
# 1039373  FE:00:00:07:69:6D    1.0             MallSur          0.0
# 1299217  FE:00:00:07:69:6D    1.0               OTHER          0.0
# 519686   FE:38:B9:9D:ED:02    1.0  CentroConvenciones          0.0
# 779530   FE:38:B9:9D:ED:02    1.0            CityMall          0.0
# 1559062  FE:38:B9:9D:ED:02    1.0         Samborondon          0.0
# 259842   FE:38:B9:9D:ED:02    1.0          Aeropuerto        100.0
# 1039374  FE:38:B9:9D:ED:02    1.0             MallSur          0.0
# 1299218  FE:38:B9:9D:ED:02    1.0               OTHER          0.0
# 779531   FE:B5:28:8B:F1:9A    1.0            CityMall          0.0
# 1039375  FE:B5:28:8B:F1:9A    1.0             MallSur          0.0
# 519687   FE:B5:28:8B:F1:9A    1.0  CentroConvenciones          0.0
# 259843   FE:B5:28:8B:F1:9A    1.0          Aeropuerto          0.0
# 1299219  FE:B5:28:8B:F1:9A    1.0               OTHER        100.0
# 1559063  FE:B5:28:8B:F1:9A    1.0         Samborondon          0.0
#
# [1559064 rows x 4 columns]

# %%
dataAnalisis3BF = dataAnalisis3B[dataAnalisis3B["%Frecuencia"] >0]
sns.lmplot('%Frecuencia', 'total',
           data=dataAnalisis3BF,
           fit_reg=False,  
           scatter_kws={"marker": "D",
                        "s": 100},size=7,aspect=3.5, hue = "localizacion")
plt.title('Histogram of IQ')
plt.xlabel('%Frecuencia')
plt.ylabel('total')
plt.show()

# %%
dataAnalisis3BF = dataAnalisis3B[dataAnalisis3B["%Frecuencia"] >0]
sns.lmplot(y='%Frecuencia', x='total',
           data=dataAnalisis3BF,
           fit_reg=False,  
           scatter_kws={"marker": "D",
                        "s": 100},size=10,aspect=, hue = "localizacion")
plt.title('Histogram of IQ')
plt.xlabel('%Frecuencia')
plt.ylabel('total')
plt.show()

# %%
dataAnalisis3BF = dataAnalisis3B[dataAnalisis3B["%Frecuencia"] >0]
sns.lmplot('%Frecuencia', 'total',
           data=dataAnalisis3BF,
           fit_reg=False,  
           scatter_kws={"marker": "D",
                        "s": 100},size=5, aspect=3.5, hue = "localizacion",row = "localizacion", x_jitter=.1)
plt.show()
